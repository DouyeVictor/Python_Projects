# %%
#Aurthor: Douye Victor O.
#Title: Movie Data Cleaning/Correlation with Python
#Source: https://www.kaggle.com/datasets/danielgrijalvas/movies

#Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots

# %%
# Reading data
df = pd.read_csv(r'C:\Users\douye\Desktop\Python\Python Project\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#DATA CLEANING

# Checking for missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# I checked the above columns for missing data and it showed the above percentages of null data. Given the very low percentages 
# of the nulls encountered in the columns (0.0005-0.01%), I will be dropping the empty rows using the 'dropna()' function

df = df.dropna()

# %%
# Running again to check for empty rows
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Checking for datatypes present in the dataframe
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing data type column for budget, gross and runtime to integer
df_copy = df.copy()
df_copy['budget'] = df_copy['budget'].astype('int')
df_copy['gross'] = df_copy['gross'].astype('int')
df_copy['runtime'] = df_copy['runtime'].astype('int')

# %%
#Assigning data frame (copy) a new name(movies)
movies = df_copy

# %%
#Viewing Movies to confirm data type change from float to integer
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#Creating Correct Year column
movies['yearcorrect'] = movies['released'].astype(str).str[:4]

# %%
# ordering by gross revenue
movies.sort_values(by=['gross'], inplace=False, ascending=False)
head_movies = movies.head()
print(head_movies)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Removing Duplicates
movies = movies.drop_duplicates()
head_of_movies = movies.head()
print(head_of_movies)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# FINDING CORRELATIONS

# %%
#Comparing Budget and Gross Revenue
#Scatter plot with Budget vs Gross
plt.scatter(x=movies['budget'], y=movies['gross'], c = 'magenta')
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for film')
plt.ylim(0, None)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Plotting budget vs gross using seaborn
#Setting up figure and axes
fig, ax = plt.subplots()
#Plotting the regression line with sector points
sns.regplot(x='budget', y='gross', scatter_kws={"color":"gold"}, line_kws={"color":"green"}, data=movies, ax=ax,)
#Setting the lower limit of y axis to zero
ax.set_ylim(0, None)
# Out:
# (0.0, 2280371967.4)

# %%
#Determining the Correlation (for numerical fields)
movies.corr(method ='pearson')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
#High Correllation between budget and gross

# %%
correlation_matrix = movies.corr(method ='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric feeatures')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Looking at company
movies.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0   699       46  19000000   46998772     1426      146           11
# 1   214       47   4500000   58853106      452      104           10
# 2  1157       47  18000000  538375067      945      124           11
# 3  1474       47   3500000   83453539     1108       88           10
# 4   271       47   6000000   39846344     1083       98           10

# %%
movies_numeric = movies
for col_name in movies_numeric.columns:
    if(movies_numeric[col_name].dtype == 'object'):
        movies_numeric[col_name] = movies_numeric[col_name].astype('category')
        movies_numeric[col_name] = movies_numeric[col_name].cat.codes
movies_numeric.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0   699       46  19000000   46998772     1426      146           11
# 1   214       47   4500000   58853106      452      104           10
# 2  1157       47  18000000  538375067      945      124           11
# 3  1474       47   3500000   83453539     1108       88           10
# 4   271       47   6000000   39846344     1083       98           10

# %%
correlation_matrix = movies_numeric.corr(method ='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric feeatures')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
movies_numeric.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlation_mat = movies_numeric.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs.head(15)
# Out:
# name  name        1.000000
#       rating     -0.029234
#       genre       0.010996
#       year        0.025542
#       released   -0.006152
#       score       0.014450
#       votes       0.012615
#       director    0.015246
#       writer      0.012880
#       star       -0.006882
#       country    -0.025490
#       budget      0.023392
#       gross       0.014073
#       company     0.021697
#       runtime     0.010850
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values
sorted_pairs
# Out:
# <bound method Series.sort_values of name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#                               ...
# yearcorrect  budget         0.018328
#              gross          0.024126
#              company       -0.002361
#              runtime        0.007167
#              yearcorrect    1.000000
# Length: 256, dtype: float64>

# %%
#Insights
#Votes and Budget have the highest correlation to Gross
#company, Genre and Rating has low correlation to Gross earnings
